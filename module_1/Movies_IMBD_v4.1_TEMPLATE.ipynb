# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter

# %%
data = pd.read_csv('movie_bd_v5.csv')
data.sample(5)
# Out:
#         imdb_id    budget   revenue              original_title  \
# 1632  tt0372588  32000000  50907422  Team America: World Police
# 297   tt0929632  10000000  63647833                    Precious
# 699   tt0959337  35000000  75225693          Revolutionary Road
# 1873  tt0160009  40000000  30199105              The Art of War
# 1745  tt0808279  15000000   7938872                 Funny Games
#
#                                                    cast          director  \
# 1632  Trey Parker|Matt Stone|Kristen Miller|Masasa M...       Trey Parker
# 297   Gabourey Sidibe|Mo'Nique|Paula Patton|Mariah C...       Lee Daniels
# 699   Leonardo DiCaprio|Kate Winslet|Michael Shannon...        Sam Mendes
# 1873  Wesley Snipes|Donald Sutherland|Maury Chaykin|...  Christian Duguay
# 1745  Naomi Watts|Tim Roth|Michael Pitt|Brady Corbet...    Michael Haneke
#
#                                                 tagline  \
# 1632                  Putting The 'F' back in 'Freedom'
# 297   Life is hard. Life is short. Life is painful. ...
# 699       How do you break free without breaking apart?
# 1873                                   Who is your foe?
# 1745                             Let the games begin...
#
#                                                overview  runtime  \
# 1632  Team America World Police follows an internati...       98
# 297   Set in Harlem in 1987, claireece "Precious" Jo...      110
# 699   A young couple living in a Connecticut suburb ...      119
# 1873  When ruthless terrorists threaten to bring dow...      117
# 1745  When Ann, husband George and son Georgie arriv...      112
#
#                                        genres  \
# 1632  Music|Adventure|Animation|Action|Comedy
# 297                                     Drama
# 699                             Drama|Romance
# 1873                Action|Adventure|Thriller
# 1745                    Horror|Thriller|Crime
#
#                                    production_companies release_date  \
# 1632         Paramount Pictures|Scott Rudin Productions   10/11/2004
# 297                       Smokewood Entertainment Group    11/6/2009
# 699   DreamWorks SKG|Scott Rudin Productions|BBC Fil...   12/19/2008
# 1873  Amen Ra Films|Franchise Pictures|Warner Bros.|...    8/23/2000
# 1745                 Halcyon Pictures|Kinematograf Wien   10/20/2007
#
#       vote_average  release_year
# 1632           6.5          2004
# 297            6.8          2009
# 699            6.5          2008
# 1873           5.7          2000
# 1745           6.2          2007

# %%
data.describe()
# Out:
#              budget       revenue      runtime  vote_average  release_year
# count  1.889000e+03  1.889000e+03  1889.000000   1889.000000   1889.000000
# mean   5.431083e+07  1.553653e+08   109.658549      6.140762   2007.860773
# std    4.858721e+07  2.146698e+08    18.017041      0.764763      4.468841
# min    5.000000e+06  2.033165e+06    63.000000      3.300000   2000.000000
# 25%    2.000000e+07  3.456058e+07    97.000000      5.600000   2004.000000
# 50%    3.800000e+07  8.361541e+07   107.000000      6.100000   2008.000000
# 75%    7.200000e+07  1.782626e+08   120.000000      6.600000   2012.000000
# max    3.800000e+08  2.781506e+09   214.000000      8.100000   2015.000000

# %% [markdown]
# # Предобработка

# %%
answers = {} # создадим словарь для ответов

# тут другие ваши предобработки колонок например:

#the time given in the dataset is in string format.
#So we need to change this in datetime format
# ...

data['profit'] = data['revenue'] - data['budget']
data.head()
# Out:
#      imdb_id     budget     revenue                original_title  \
# 0  tt0369610  150000000  1513528810                Jurassic World
# 1  tt1392190  150000000   378436354            Mad Max: Fury Road
# 2  tt2908446  110000000   295238201                     Insurgent
# 3  tt2488496  200000000  2068178225  Star Wars: The Force Awakens
# 4  tt2820852  190000000  1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                          tagline  \
# 0              The park is open.
# 1             What a Lovely Day.
# 2     One Choice Can Destroy You
# 3  Every generation has a story.
# 4            Vengeance Hits Home
#
#                                             overview  runtime  \
# 0  Twenty-two years after the events of Jurassic ...      124
# 1  An apocalyptic story set in the furthest reach...      120
# 2  Beatrice Prior must confront her inner demons ...      119
# 3  Thirty years after defeating the Galactic Empi...      136
# 4  Deckard Shaw seeks revenge against Dominic Tor...      137
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
# 3   Action|Adventure|Science Fiction|Fantasy
# 4                      Action|Crime|Thriller
#
#                                 production_companies release_date  \
# 0  Universal Studios|Amblin Entertainment|Legenda...     6/9/2015
# 1  Village Roadshow Pictures|Kennedy Miller Produ...    5/13/2015
# 2  Summit Entertainment|Mandeville Films|Red Wago...    3/18/2015
# 3          Lucasfilm|Truenorth Productions|Bad Robot   12/15/2015
# 4  Universal Pictures|Original Film|Media Rights ...     4/1/2015
#
#    vote_average  release_year      profit
# 0           6.5          2015  1363528810
# 1           7.1          2015   228436354
# 2           6.3          2015   185238201
# 3           7.5          2015  1868178225
# 4           7.3          2015  1316249360

# %% [markdown]
# # 1. У какого фильма из списка самый большой бюджет?

# %% [markdown]
# Использовать варианты ответов в коде решения запрещено.
# Вы думаете и в жизни у вас будут варианты ответов?)

# %%
# в словарь вставляем номер вопроса и ваш ответ на него
# Пример: 
#answers['1'] = '2. Spider-Man 3 (tt0413300)'
# запишите свой вариант ответа
answers['1'] = '5. Pirates of the Caribbean: On Stranger Tides (tt1298650) '
# если ответили верно, можете добавить комментарий со значком "+"

# %%
# тут пишем ваш код для решения данного вопроса:
data[data['budget'] == data['budget'].max()]
# Out:
#        imdb_id     budget     revenue  \
# 723  tt1298650  380000000  1021683000
#
#                                   original_title  \
# 723  Pirates of the Caribbean: On Stranger Tides
#
#                                                   cast      director  \
# 723  Johnny Depp|PenÃ©lope Cruz|Geoffrey Rush|Ian M...  Rob Marshall
#
#                          tagline  \
# 723  Live Forever Or Die Trying.
#
#                                               overview  runtime  \
# 723  Captain Jack Sparrow crosses paths with a woma...      136
#
#                        genres  \
# 723  Adventure|Action|Fantasy
#
#                                   production_companies release_date  \
# 723  Walt Disney Pictures|Jerry Bruckheimer Films|M...    5/11/2011
#
#      vote_average  release_year
# 723           6.3          2011

# %% [markdown]
# ВАРИАНТ 2

# %%
# можно добавлять разные варианты решения

# %% [markdown]
# # 2. Какой из фильмов самый длительный (в минутах)?

# %%
# думаю логику работы с этим словарем вы уже поняли, 
# по этому не буду больше его дублировать
answers['2'] = '2. Gods and Generals (tt0279111) '

# %%
data[data['runtime'] == data['runtime'].max()]
# Out:
#         imdb_id    budget   revenue     original_title  \
# 1157  tt0279111  56000000  12923936  Gods and Generals
#
#                                                    cast           director  \
# 1157  Stephen Lang|Jeff Daniels|Robert Duvall|Kevin ...  Ronald F. Maxwell
#
#                                   tagline  \
# 1157  The nations heart was touched by...
#
#                                                overview  runtime  \
# 1157  The film centers mostly around the personal an...      214
#
#                  genres                production_companies release_date  \
# 1157  Drama|History|War  Turner Pictures|Antietam Filmworks    2/21/2003
#
#       vote_average  release_year
# 1157           5.8          2003

# %% [markdown]
# # 3. Какой из фильмов самый короткий (в минутах)?

# %%
data[data['runtime'] == data['runtime'].min()]
# Out:
#        imdb_id    budget   revenue   original_title  \
# 768  tt1449283  30000000  14460000  Winnie the Pooh
#
#                                                   cast  \
# 768  Jim Cummings|Travis Oates|Jim Cummings|Bud Luc...
#
#                       director   tagline  \
# 768  Stephen Anderson|Don Hall  Oh Pooh.
#
#                                               overview  runtime  \
# 768  During an ordinary day in Hundred Acre Wood, W...       63
#
#                genres                               production_companies  \
# 768  Animation|Family  Walt Disney Pictures|Walt Disney Animation Stu...
#
#     release_date  vote_average  release_year
# 768    4/13/2011           6.8          2011

# %%
answers['3'] = '3. Winnie the Pooh (tt1449283) '

# %% [markdown]
# # 4. Какова средняя длительность фильмов?

# %%
total_time = data['runtime'].mean()
total_time
# Out:
# 109.6585494970884

# %%
answers['4'] = '2. 110'

# %% [markdown]
# # 5. Каково медианное значение длительности фильмов?

# %%
data['runtime'].median()
# Out:
# 107.0

# %%
answers['5'] = '1. 107'

# %% [markdown]
# # 6. Какой самый прибыльный фильм?
# #### Внимание! Здесь и далее под «прибылью» или «убытками» понимается разность между сборами и бюджетом фильма. (прибыль = сборы - бюджет) в нашем датасете это будет (profit = revenue - budget)

# %%
# лучше код получения столбца profit вынести в Предобработку что в начале
data[data['profit'] == data['profit'].max()]
# Out:
#        imdb_id     budget     revenue original_title  \
# 239  tt0499549  237000000  2781505847         Avatar
#
#                                                   cast       director  \
# 239  Sam Worthington|Zoe Saldana|Sigourney Weaver|S...  James Cameron
#
#                          tagline  \
# 239  Enter the World of Pandora.
#
#                                               overview  runtime  \
# 239  In the 22nd century, a paraplegic Marine is di...      162
#
#                                        genres  \
# 239  Action|Adventure|Fantasy|Science Fiction
#
#                                   production_companies release_date  \
# 239  Ingenious Film Partners|Twentieth Century Fox ...   12/10/2009
#
#      vote_average  release_year      profit
# 239           7.1          2009  2544505847

# %%
answers['6'] = '5. Avatar (tt0499549) '

# %% [markdown]
# # 7. Какой фильм самый убыточный?

# %%
data[data['profit'] == data['profit'].min()]
# Out:
#         imdb_id     budget   revenue   original_title  \
# 1245  tt1210819  255000000  89289910  The Lone Ranger
#
#                                                    cast        director  \
# 1245  Johnny Depp|Armie Hammer|William Fichtner|Hele...  Gore Verbinski
#
#                       tagline  \
# 1245  Never Take Off the Mask
#
#                                                overview  runtime  \
# 1245  The Texas Rangers chase down a gang of outlaws...      149
#
#                         genres  \
# 1245  Action|Adventure|Western
#
#                                    production_companies release_date  \
# 1245  Walt Disney Pictures|Jerry Bruckheimer Films|I...     7/3/2013
#
#       vote_average  release_year     profit
# 1245           6.0          2013 -165710090

# %%
answers['7'] = '5. The Lone Ranger (tt1210819) '

# %% [markdown]
# # 8. У скольких фильмов из датасета объем сборов оказался выше бюджета?

# %%
data[data['revenue']>data['budget']].count()
# Out:
# imdb_id                 1478
# budget                  1478
# revenue                 1478
# original_title          1478
# cast                    1478
# director                1478
# tagline                 1478
# overview                1478
# runtime                 1478
# genres                  1478
# production_companies    1478
# release_date            1478
# vote_average            1478
# release_year            1478
# profit                  1478
# dtype: int64

# %%
answers['8'] = '1. 1478'

# %% [markdown]
# # 9. Какой фильм оказался самым кассовым в 2008 году?

# %%
data_2008 = data[(data['release_year'] == 2008)]
data_2008[data_2008['profit'] == data_2008['profit'].max()]
# Out:
#        imdb_id     budget     revenue   original_title  \
# 599  tt0468569  185000000  1001921825  The Dark Knight
#
#                                                   cast           director  \
# 599  Christian Bale|Michael Caine|Heath Ledger|Aaro...  Christopher Nolan
#
#              tagline                                           overview  \
# 599  Why So Serious?  Batman raises the stakes in his war on crime. ...
#
#      runtime                       genres  \
# 599      152  Drama|Action|Crime|Thriller
#
#                                   production_companies release_date  \
# 599  DC Comics|Legendary Pictures|Warner Bros.|Syncopy    7/16/2008
#
#      vote_average  release_year     profit
# 599           8.1          2008  816921825

# %%
answers['9'] = '4. The Dark Knight (tt0468569) '

# %%
data.query('release_year == 2008').head(3)
# Out:
#        imdb_id     budget     revenue   original_title  \
# 599  tt0468569  185000000  1001921825  The Dark Knight
# 600  tt0910970  180000000   521311860          WALLÂ·E
# 601  tt0371746  140000000   585174222         Iron Man
#
#                                                   cast           director  \
# 599  Christian Bale|Michael Caine|Heath Ledger|Aaro...  Christopher Nolan
# 600  Ben Burtt|Elissa Knight|Jeff Garlin|Fred Willa...     Andrew Stanton
# 601  Robert Downey Jr.|Terrence Howard|Jeff Bridges...        Jon Favreau
#
#                                 tagline  \
# 599                     Why So Serious?
# 600  An adventure beyond the ordinar-E.
# 601  Heroes aren't born. They're built.
#
#                                               overview  runtime  \
# 599  Batman raises the stakes in his war on crime. ...      152
# 600  WALLÂ·E is the last robot left on an Earth tha...       98
# 601  After being held captive in an Afghan cave, bi...      126
#
#                                genres  \
# 599       Drama|Action|Crime|Thriller
# 600                  Animation|Family
# 601  Action|Science Fiction|Adventure
#
#                                   production_companies release_date  \
# 599  DC Comics|Legendary Pictures|Warner Bros.|Syncopy    7/16/2008
# 600       Walt Disney Pictures|Pixar Animation Studios    6/22/2008
# 601                                     Marvel Studios    4/30/2008
#
#      vote_average  release_year     profit
# 599           8.1          2008  816921825
# 600           7.6          2008  341311860
# 601           7.3          2008  445174222

# %% [markdown]
# # 10. Самый убыточный фильм за период с 2012 по 2014 г. (включительно)?

# %%
years_12_14 = data.query('2012 <= release_year <= 2014')
years_12_14[years_12_14.profit == years_12_14.profit.min()]
# Out:
#         imdb_id     budget   revenue   original_title  \
# 1245  tt1210819  255000000  89289910  The Lone Ranger
#
#                                                    cast        director  \
# 1245  Johnny Depp|Armie Hammer|William Fichtner|Hele...  Gore Verbinski
#
#                       tagline  \
# 1245  Never Take Off the Mask
#
#                                                overview  runtime  \
# 1245  The Texas Rangers chase down a gang of outlaws...      149
#
#                         genres  \
# 1245  Action|Adventure|Western
#
#                                    production_companies release_date  \
# 1245  Walt Disney Pictures|Jerry Bruckheimer Films|I...     7/3/2013
#
#       vote_average  release_year     profit
# 1245           6.0          2013 -165710090

# %%
answers['10'] ='5. The Lone Ranger (tt1210819) '

# %% [markdown]
# # 11. Какого жанра фильмов больше всего?

# %%
# эту задачу тоже можно решать разными подходами, попробуй реализовать разные варианты
# если будешь добавлять функцию - выноси ее в предобработку что в начале
data.genres.value_counts()
# Out:
# Comedy                                            141
# Drama                                             102
# Comedy|Romance                                     60
# Drama|Romance                                      45
# Horror|Thriller                                    35
#                                                  ...
# Action|Adventure|Comedy|Drama|Mystery               1
# Animation|Action|Comedy|Family|Science Fiction      1
# Adventure|Action|Family                             1
# Drama|Music|Adventure|Fantasy                       1
# Thriller|Science Fiction|Action                     1
# Name: genres, Length: 652, dtype: int64

# %% [markdown]
# ВАРИАНТ 2

# %%
data.groupby(['genres'])['imdb_id'].nunique().sort_values( ascending = False)
# Out:
# genres
# Comedy                            141
# Drama                             102
# Comedy|Romance                     60
# Drama|Romance                      45
# Comedy|Drama|Romance               35
#                                  ...
# Drama|Mystery|Thriller|Fantasy      1
# Drama|Mystery|Thriller|Horror       1
# Drama|Romance|Comedy                1
# Drama|Romance|Comedy|Music          1
# Crime|Comedy|Romance                1
# Name: imdb_id, Length: 652, dtype: int64

# %%
answers['11'] = '3. Drama'

# %%
data.genres.str.split('|', expand = True).stack().value_counts()
# Out:
# Drama              782
# Comedy             683
# Thriller           596
# Action             582
# Adventure          415
# Crime              315
# Romance            308
# Family             260
# Science Fiction    248
# Fantasy            222
# Horror             176
# Mystery            168
# Animation          139
# Music               64
# History             62
# War                 58
# Western             19
# Documentary          8
# Foreign              2
# dtype: int64

# %% [markdown]
# # 12. Фильмы какого жанра чаще всего становятся прибыльными?

# %%
data.groupby(['genres'])['profit'].count().sort_values(ascending = False)
# Out:
# genres
# Comedy                            141
# Drama                             102
# Comedy|Romance                     60
# Drama|Romance                      45
# Comedy|Drama|Romance               35
#                                  ...
# Drama|Mystery|Thriller|Fantasy      1
# Drama|Mystery|Thriller|Horror       1
# Drama|Romance|Comedy                1
# Drama|Romance|Comedy|Music          1
# Crime|Comedy|Romance                1
# Name: profit, Length: 652, dtype: int64

# %%
data.groupby(['genres'])['profit'].mean().sort_values(ascending = False)
# Out:
# genres
# Action|Adventure|Science Fiction|Fantasy     1.868178e+09
# Family|Fantasy|Adventure                     8.254671e+08
# Drama|Action|Crime|Thriller                  8.169218e+08
# Adventure|Fantasy|Family|Mystery             7.882127e+08
# Science Fiction|Thriller|Action|Adventure    7.174235e+08
#                                                  ...
# Mystery|Crime|Action|Thriller|Drama         -5.224706e+07
# Fantasy|Action|Comedy|Crime                 -6.835150e+07
# Thriller|Science Fiction|Adventure|Action   -7.401036e+07
# Western|History|War                         -1.191800e+08
# Action|Adventure|Western                    -1.657101e+08
# Name: profit, Length: 652, dtype: float64

# %%
data_profit = data[data['profit']>0]
data_profit.head()
# Out:
#      imdb_id     budget     revenue                original_title  \
# 0  tt0369610  150000000  1513528810                Jurassic World
# 1  tt1392190  150000000   378436354            Mad Max: Fury Road
# 2  tt2908446  110000000   295238201                     Insurgent
# 3  tt2488496  200000000  2068178225  Star Wars: The Force Awakens
# 4  tt2820852  190000000  1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                          tagline  \
# 0              The park is open.
# 1             What a Lovely Day.
# 2     One Choice Can Destroy You
# 3  Every generation has a story.
# 4            Vengeance Hits Home
#
#                                             overview  runtime  \
# 0  Twenty-two years after the events of Jurassic ...      124
# 1  An apocalyptic story set in the furthest reach...      120
# 2  Beatrice Prior must confront her inner demons ...      119
# 3  Thirty years after defeating the Galactic Empi...      136
# 4  Deckard Shaw seeks revenge against Dominic Tor...      137
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
# 3   Action|Adventure|Science Fiction|Fantasy
# 4                      Action|Crime|Thriller
#
#                                 production_companies release_date  \
# 0  Universal Studios|Amblin Entertainment|Legenda...     6/9/2015
# 1  Village Roadshow Pictures|Kennedy Miller Produ...    5/13/2015
# 2  Summit Entertainment|Mandeville Films|Red Wago...    3/18/2015
# 3          Lucasfilm|Truenorth Productions|Bad Robot   12/15/2015
# 4  Universal Pictures|Original Film|Media Rights ...     4/1/2015
#
#    vote_average  release_year      profit
# 0           6.5          2015  1363528810
# 1           7.1          2015   228436354
# 2           6.3          2015   185238201
# 3           7.5          2015  1868178225
# 4           7.3          2015  1316249360

# %%
data_profit['genres'].value_counts()
# Out:
# Comedy                                       121
# Drama                                         70
# Comedy|Romance                                52
# Drama|Romance                                 38
# Horror|Thriller                               31
#                                             ...
# Animation|Comedy|Family|Adventure|Fantasy      1
# Drama|Action|Thriller|War                      1
# Action|Comedy|Crime|Drama|Music                1
# Action|Science Fiction|Drama                   1
# Thriller|Science Fiction|Action                1
# Name: genres, Length: 548, dtype: int64

# %%
data['genres'].value_counts(normalize = True)
# Out:
# Comedy                                            0.074643
# Drama                                             0.053997
# Comedy|Romance                                    0.031763
# Drama|Romance                                     0.023822
# Horror|Thriller                                   0.018528
#                                                     ...
# Action|Adventure|Comedy|Drama|Mystery             0.000529
# Animation|Action|Comedy|Family|Science Fiction    0.000529
# Adventure|Action|Family                           0.000529
# Drama|Music|Adventure|Fantasy                     0.000529
# Thriller|Science Fiction|Action                   0.000529
# Name: genres, Length: 652, dtype: float64

# %%
answers['12'] = '1. Drama'

# %%
data_genres = data.assign(genres = data.genres.str.split('|')).explode('genres').reset_index(drop = True)
data_genres.head(2)
# Out:
#      imdb_id     budget     revenue  original_title  \
# 0  tt0369610  150000000  1513528810  Jurassic World
# 1  tt0369610  150000000  1513528810  Jurassic World
#
#                                                 cast         director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  Colin Trevorrow
# 1  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  Colin Trevorrow
#
#              tagline                                           overview  \
# 0  The park is open.  Twenty-two years after the events of Jurassic ...
# 1  The park is open.  Twenty-two years after the events of Jurassic ...
#
#    runtime     genres                               production_companies  \
# 0      124     Action  Universal Studios|Amblin Entertainment|Legenda...
# 1      124  Adventure  Universal Studios|Amblin Entertainment|Legenda...
#
#   release_date  vote_average  release_year      profit
# 0     6/9/2015           6.5          2015  1363528810
# 1     6/9/2015           6.5          2015  1363528810

# %%
data_genres[data_genres['profit']>0]['genres'].value_counts()
# Out:
# Drama              560
# Comedy             551
# Thriller           446
# Action             444
# Adventure          337
# Romance            242
# Crime              231
# Family             226
# Science Fiction    195
# Fantasy            188
# Horror             150
# Animation          120
# Mystery            119
# Music               47
# History             46
# War                 41
# Western             12
# Documentary          7
# Name: genres, dtype: int64

# %% [markdown]
# # 13. У какого режиссера самые большие суммарные кассовые сбооры?

# %%
data.groupby(['director'])['revenue'].sum().sort_values(ascending = False)
# Out:
# director
# Peter Jackson        6490593685
# Christopher Nolan    4167548502
# David Yates          4154295625
# Michael Bay          3886938960
# J.J. Abrams          3579169916
#                         ...
# David MichÃ´d           2295423
# Steven Shainberg        2281089
# Paul Schrader           2062066
# Keanu Reeves            2054941
# Simon Hunter            2033165
# Name: revenue, Length: 957, dtype: int64

# %%
answers['13'] = '5. Peter Jackson '
answers
# Out:
# {'6': '5. Avatar (tt0499549) ',
#  '7': '5. The Lone Ranger (tt1210819) ',
#  '8': '1. 1478',
#  '9': '4. The Dark Knight (tt0468569) ',
#  '10': '5. The Lone Ranger (tt1210819) ',
#  '11': '4. Comedy',
#  '13': '5. Peter Jackson ',
#  '12': 'xz'}

# %% [markdown]
# # 14. Какой режисер снял больше всего фильмов в стиле Action?

# %%
data_genre = data.groupby(['genres', 'director']).count().sort_values('imdb_id', ascending = False)
data_genre.loc['Action']
# Out:
#                        imdb_id  budget  revenue  original_title  cast  \
# director
# Rob Cohen                    2       2        2               2     2
# Andrew Davis                 1       1        1               1     1
# Sydney Pollack               1       1        1               1     1
# Robert Rodriguez             1       1        1               1     1
# Rob Bowman                   1       1        1               1     1
# Ridley Scott                 1       1        1               1     1
# Renny Harlin                 1       1        1               1     1
# Paul McGuigan                1       1        1               1     1
# Marcus Nispel                1       1        1               1     1
# Kevin Macdonald              1       1        1               1     1
# Joseph Kahn                  1       1        1               1     1
# John Moore                   1       1        1               1     1
# Harald Zwart                 1       1        1               1     1
# Christopher McQuarrie        1       1        1               1     1
# Andy Tennant                 1       1        1               1     1
#
#                        tagline  overview  runtime  production_companies  \
# director
# Rob Cohen                    2         2        2                     2
# Andrew Davis                 1         1        1                     1
# Sydney Pollack               1         1        1                     1
# Robert Rodriguez             1         1        1                     1
# Rob Bowman                   1         1        1                     1
# Ridley Scott                 1         1        1                     1
# Renny Harlin                 1         1        1                     1
# Paul McGuigan                1         1        1                     1
# Marcus Nispel                1         1        1                     1
# Kevin Macdonald              1         1        1                     1
# Joseph Kahn                  1         1        1                     1
# John Moore                   1         1        1                     1
# Harald Zwart                 1         1        1                     1
# Christopher McQuarrie        1         1        1                     1
# Andy Tennant                 1         1        1                     1
#
#                        release_date  vote_average  release_year  profit
# director
# Rob Cohen                         2             2             2       2
# Andrew Davis                      1             1             1       1
# Sydney Pollack                    1             1             1       1
# Robert Rodriguez                  1             1             1       1
# Rob Bowman                        1             1             1       1
# Ridley Scott                      1             1             1       1
# Renny Harlin                      1             1             1       1
# Paul McGuigan                     1             1             1       1
# Marcus Nispel                     1             1             1       1
# Kevin Macdonald                   1             1             1       1
# Joseph Kahn                       1             1             1       1
# John Moore                        1             1             1       1
# Harald Zwart                      1             1             1       1
# Christopher McQuarrie             1             1             1       1
# Andy Tennant                      1             1             1       1

# %%
data_genres['imdb_id'].sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4410             try:
# -> 4411                 return libindex.get_value_at(s, key)
#    4412             except IndexError:
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_at()
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_at()
#
# pandas\_libs\util.pxd in pandas._libs.util.get_value_at()
#
# pandas\_libs\util.pxd in pandas._libs.util.validate_indexer()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-140-eda61e979fbe> in <module>
# ----> 1 data_genres['imdb_id'].sum()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4417                     raise InvalidIndexError(key)
#    4418                 else:
# -> 4419                     raise e1
#    4420             except Exception:
#    4421                 raise e1
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4403         k = self._convert_scalar_indexer(k, kind="getitem")
#    4404         try:
# -> 4405             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4406         except KeyError as e1:
#    4407             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'imdb_id'

# %%
data_genres = data['genres'].value_counts()
data_genres.loc['Action']
# Out:
# 16

# %%
data[data['director']=='Guy Ritchie']
# Out:
#         imdb_id     budget    revenue                      original_title  \
# 40    tt1638355   75000000  108145109             The Man from U.N.C.L.E.
# 247   tt0988045   90000000  524028679                     Sherlock Holmes
# 685   tt1032755   18000000   25739015                          RockNRolla
# 740   tt1515091  125000000  334615000  Sherlock Holmes: A Game of Shadows
# 1803  tt0208092   10000000   83557872                              Snatch
#
#                                                    cast     director  \
# 40    Henry Cavill|Armie Hammer|Alicia Vikander|Eliz...  Guy Ritchie
# 247   Robert Downey Jr.|Jude Law|Rachel McAdams|Mark...  Guy Ritchie
# 685   Mark Strong|Tom Wilkinson|Toby Kebbell|Gerard ...  Guy Ritchie
# 740   Robert Downey Jr.|Jude Law|Jared Harris|Noomi ...  Guy Ritchie
# 1803  Jason Statham|Brad Pitt|Vinnie Jones|Dennis Fa...  Guy Ritchie
#
#                                         tagline  \
# 40    Saving the world never goes out of style.
# 247                        Nothing escapes him.
# 685     A story of sex, thugs and rock 'n roll.
# 740                          The Game is Afoot.
# 1803        Stealin' Stones and Breakin' Bones.
#
#                                                overview  runtime  \
# 40    At the height of the Cold War, a mysterious cr...      116
# 247   Eccentric consulting detective Sherlock Holmes...      128
# 685   When a Russian mobster sets up a real estate s...      114
# 740   There is a new criminal mastermind at large--P...      129
# 1803  The second film from British director Guy Ritc...      103
#
#                                       genres  \
# 40                   Comedy|Action|Adventure
# 247   Adventure|Drama|Action|Comedy|Thriller
# 685                    Action|Crime|Thriller
# 740           Adventure|Action|Crime|Mystery
# 1803                          Thriller|Crime
#
#                                    production_companies release_date  \
# 40    Davis Entertainment|Warner Bros.|Wigram Produc...    8/13/2015
# 247   Village Roadshow Pictures|Silver Pictures|Warn...     1/7/2009
# 685   StudioCanal|Dark Castle Entertainment|Toff Guy...     9/4/2008
# 740   Village Roadshow Pictures|Silver Pictures|Lin ...   11/22/2011
# 1803            Columbia Pictures Corporation|SKA Films     9/1/2000
#
#       vote_average  release_year     profit
# 40             7.0          2015   33145109
# 247            6.9          2009  434028679
# 685            6.8          2008    7739015
# 740            6.9          2011  209615000
# 1803           7.5          2000   73557872

# %%
data_Action = data[data.genres.str.contains('Action', na = False)]
data_Action_grouped = data_Action.groupby(['director']).count().sort_values('imdb_id', ascending = False)
data_Action_grouped
# Out:
#                          imdb_id  budget  revenue  original_title  cast  \
# director
# Paul W.S. Anderson             7       7        7               7     7
# Michael Bay                    7       7        7               7     7
# Ridley Scott                   6       6        6               6     6
# Antoine Fuqua                  6       6        6               6     6
# Robert Rodriguez               6       6        6               6     6
# ...                          ...     ...      ...             ...   ...
# Jimmy Hayward                  1       1        1               1     1
# Joe Cornish                    1       1        1               1     1
# Joe Russo|Anthony Russo        1       1        1               1     1
# Joe Wright                     1       1        1               1     1
# Jorma Taccone                  1       1        1               1     1
#
#                          tagline  overview  runtime  genres  \
# director
# Paul W.S. Anderson             7         7        7       7
# Michael Bay                    7         7        7       7
# Ridley Scott                   6         6        6       6
# Antoine Fuqua                  6         6        6       6
# Robert Rodriguez               6         6        6       6
# ...                          ...       ...      ...     ...
# Jimmy Hayward                  1         1        1       1
# Joe Cornish                    1         1        1       1
# Joe Russo|Anthony Russo        1         1        1       1
# Joe Wright                     1         1        1       1
# Jorma Taccone                  1         1        1       1
#
#                          production_companies  release_date  vote_average  \
# director
# Paul W.S. Anderson                          7             7             7
# Michael Bay                                 7             7             7
# Ridley Scott                                6             6             6
# Antoine Fuqua                               6             6             6
# Robert Rodriguez                            6             6             6
# ...                                       ...           ...           ...
# Jimmy Hayward                               1             1             1
# Joe Cornish                                 1             1             1
# Joe Russo|Anthony Russo                     1             1             1
# Joe Wright                                  1             1             1
# Jorma Taccone                               1             1             1
#
#                          release_year  profit
# director
# Paul W.S. Anderson                  7       7
# Michael Bay                         7       7
# Ridley Scott                        6       6
# Antoine Fuqua                       6       6
# Robert Rodriguez                    6       6
# ...                               ...     ...
# Jimmy Hayward                       1       1
# Joe Cornish                         1       1
# Joe Russo|Anthony Russo             1       1
# Joe Wright                          1       1
# Jorma Taccone                       1       1
#
# [345 rows x 14 columns]

# %%
data_Action = data[data.genres.str.contains('Action', na = False)]
data_Action['director'].str.split('|', expand = True).stack().value_counts()
# Out:
# Robert Rodriguez      9
# Michael Bay           7
# Paul W.S. Anderson    7
# Ridley Scott          6
# Antoine Fuqua         6
#                      ..
# Rob Minkoff           1
# Stephen Norrington    1
# Mathieu Kassovitz     1
# Alister Grierson      1
# George Miller         1
# Length: 364, dtype: int64

# %%
data_Action_grouped.loc['Robert Rodriguez']
# Out:
# imdb_id                 6
# budget                  6
# revenue                 6
# original_title          6
# cast                    6
# tagline                 6
# overview                6
# runtime                 6
# genres                  6
# production_companies    6
# release_date            6
# vote_average            6
# release_year            6
# profit                  6
# Name: Robert Rodriguez, dtype: int64

# %%
answers['14'] = '3. Robert Rodriguez'

# %% [markdown]
# # 15. Фильмы с каким актером принесли самые высокие кассовые сборы в 2012 году?

# %%
data.columns
# Out:
# Index(['imdb_id', 'budget', 'revenue', 'original_title', 'cast', 'director',
#        'tagline', 'overview', 'runtime', 'genres', 'production_companies',
#        'release_date', 'vote_average', 'release_year', 'profit'],
#       dtype='object')

# %%
data[(data['release_date'] == 2012) & (data['revenue'] == data['revenue'].max())]
# Out:
# Empty DataFrame
# Columns: [imdb_id, budget, revenue, original_title, cast, director, tagline, overview, runtime, genres, production_companies, release_date, vote_average, release_year, profit]
# Index: []

# %%
data.groupby(['release_date'])['revenue'].max().sort_values(ascending = False)
# Out:
# release_date
# 12/10/2009    2781505847
# 12/15/2015    2068178225
# 4/25/2012     1519557910
# 6/9/2015      1513528810
# 4/1/2015      1506249360
#                  ...
# 9/17/2014        2367161
# 9/7/2014         2360281
# 5/18/2014        2295423
# 8/30/2006        2281089
# 7/4/2013         2054941
# Name: revenue, Length: 1435, dtype: int64

# %%
data_2012 = data[data.release_date.str.contains('2012', na = False)]
data_2012.head()
# Out:
#        imdb_id     budget     revenue         original_title  \
# 970  tt0848228  220000000  1519557910           The Avengers
# 971  tt1496025   70000000   132400000  Underworld: Awakening
# 972  tt1345836  250000000  1081041287  The Dark Knight Rises
# 973  tt1853728  100000000   425368238       Django Unchained
# 974  tt1074638  200000000  1108561013                Skyfall
#
#                                                   cast  \
# 970  Robert Downey Jr.|Chris Evans|Mark Ruffalo|Chr...
# 971  Kate Beckinsale|Stephen Rea|Michael Ealy|Theo ...
# 972  Christian Bale|Michael Caine|Gary Oldman|Anne ...
# 973  Jamie Foxx|Christoph Waltz|Leonardo DiCaprio|K...
# 974  Daniel Craig|Judi Dench|Javier Bardem|Ralph Fi...
#
#                         director                                      tagline  \
# 970                  Joss Whedon                      Some assembly required.
# 971  MÃ¥ns MÃ¥rlind|BjÃ¶rn Stein                            Vengeance Returns
# 972            Christopher Nolan                              The Legend Ends
# 973            Quentin Tarantino  Life, liberty and the pursuit of vengeance.
# 974                   Sam Mendes                          Think on your sins.
#
#                                               overview  runtime  \
# 970  When an unexpected enemy emerges and threatens...      143
# 971  After being held in a coma-like state for fift...       88
# 972  Following the death of District Attorney Harve...      165
# 973  With the help of a German bounty hunter, a fre...      165
# 974  When Bond's latest assignment goes gravely wro...      143
#
#                                genres  \
# 970  Science Fiction|Action|Adventure
# 971             Fantasy|Action|Horror
# 972       Action|Crime|Drama|Thriller
# 973                     Drama|Western
# 974         Action|Adventure|Thriller
#
#                                   production_companies release_date  \
# 970                                     Marvel Studios    4/25/2012
# 971  Lakeshore Entertainment|Saturn Films|Screen Ge...    1/19/2012
# 972  Legendary Pictures|Warner Bros.|DC Entertainme...    7/16/2012
# 973            Columbia Pictures|The Weinstein Company   12/25/2012
# 974                                  Columbia Pictures   10/25/2012
#
#      vote_average  release_year      profit
# 970           7.3          2012  1299557910
# 971           6.0          2012    62400000
# 972           7.5          2012   831041287
# 973           7.7          2012   325368238
# 974           6.8          2012   908561013

# %%
data_2012_cast = data_2012.assign(cast = data_2012.cast.str.split('|')).explode('cast').reset_index(drop=True)
data_2012_cast.head()
# Out:
#      imdb_id     budget     revenue original_title                cast  \
# 0  tt0848228  220000000  1519557910   The Avengers   Robert Downey Jr.
# 1  tt0848228  220000000  1519557910   The Avengers         Chris Evans
# 2  tt0848228  220000000  1519557910   The Avengers        Mark Ruffalo
# 3  tt0848228  220000000  1519557910   The Avengers     Chris Hemsworth
# 4  tt0848228  220000000  1519557910   The Avengers  Scarlett Johansson
#
#       director                  tagline  \
# 0  Joss Whedon  Some assembly required.
# 1  Joss Whedon  Some assembly required.
# 2  Joss Whedon  Some assembly required.
# 3  Joss Whedon  Some assembly required.
# 4  Joss Whedon  Some assembly required.
#
#                                             overview  runtime  \
# 0  When an unexpected enemy emerges and threatens...      143
# 1  When an unexpected enemy emerges and threatens...      143
# 2  When an unexpected enemy emerges and threatens...      143
# 3  When an unexpected enemy emerges and threatens...      143
# 4  When an unexpected enemy emerges and threatens...      143
#
#                              genres production_companies release_date  \
# 0  Science Fiction|Action|Adventure       Marvel Studios    4/25/2012
# 1  Science Fiction|Action|Adventure       Marvel Studios    4/25/2012
# 2  Science Fiction|Action|Adventure       Marvel Studios    4/25/2012
# 3  Science Fiction|Action|Adventure       Marvel Studios    4/25/2012
# 4  Science Fiction|Action|Adventure       Marvel Studios    4/25/2012
#
#    vote_average  release_year      profit
# 0           7.3          2012  1299557910
# 1           7.3          2012  1299557910
# 2           7.3          2012  1299557910
# 3           7.3          2012  1299557910
# 4           7.3          2012  1299557910

# %%
data_2012_cast.groupby(['cast'])['revenue'].sum().sort_values(ascending = False)
# Out:
# cast
# Chris Hemsworth      2027450773
# Denis Leary          1629460639
# Anne Hathaway        1522851057
# Chris Evans          1519557910
# Robert Downey Jr.    1519557910
#                         ...
# Jason Bateman           3428048
# Danny Huston            2106557
# Sami Gayle              2106557
# Josh Lucas              2106557
# Nicolas Cage            2106557
# Name: revenue, Length: 466, dtype: int64

# %%
answers['15'] = '3. Chris Hemsworth'

# %%
df = pd.DataFrame({'A': [[1, 2, 3], 'foo', [], [3, 4]], 'B': 1})
df
# Out:
#            A  B
# 0  [1, 2, 3]  1
# 1        foo  1
# 2         []  1
# 3     [3, 4]  1

# %%
df.explode('A')
# Out:
#      A  B
# 0    1  1
# 0    2  1
# 0    3  1
# 1  foo  1
# 2  NaN  1
# 3    3  1
# 3    4  1

# %% [markdown]
# # 16. Какой актер снялся в большем количестве высокобюджетных фильмов?

# %%
data.describe()
# Out:
#              budget       revenue      runtime  vote_average  release_year  \
# count  1.889000e+03  1.889000e+03  1889.000000   1889.000000   1889.000000
# mean   5.431083e+07  1.553653e+08   109.658549      6.140762   2007.860773
# std    4.858721e+07  2.146698e+08    18.017041      0.764763      4.468841
# min    5.000000e+06  2.033165e+06    63.000000      3.300000   2000.000000
# 25%    2.000000e+07  3.456058e+07    97.000000      5.600000   2004.000000
# 50%    3.800000e+07  8.361541e+07   107.000000      6.100000   2008.000000
# 75%    7.200000e+07  1.782626e+08   120.000000      6.600000   2012.000000
# max    3.800000e+08  2.781506e+09   214.000000      8.100000   2015.000000
#
#              profit
# count  1.889000e+03
# mean   1.010545e+08
# std    1.830733e+08
# min   -1.657101e+08
# 25%    5.000000e+06
# 50%    4.400041e+07
# 75%    1.201842e+08
# max    2.544506e+09

# %%
mean_budget = data.budget.mean()
mean_budget
# Out:
# 54310829.63843303

# %%
data_high_budget = data[data.budget.apply(lambda x: x> mean_budget)]
data_high_budget.head()
# Out:
#      imdb_id     budget     revenue                original_title  \
# 0  tt0369610  150000000  1513528810                Jurassic World
# 1  tt1392190  150000000   378436354            Mad Max: Fury Road
# 2  tt2908446  110000000   295238201                     Insurgent
# 3  tt2488496  200000000  2068178225  Star Wars: The Force Awakens
# 4  tt2820852  190000000  1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                          tagline  \
# 0              The park is open.
# 1             What a Lovely Day.
# 2     One Choice Can Destroy You
# 3  Every generation has a story.
# 4            Vengeance Hits Home
#
#                                             overview  runtime  \
# 0  Twenty-two years after the events of Jurassic ...      124
# 1  An apocalyptic story set in the furthest reach...      120
# 2  Beatrice Prior must confront her inner demons ...      119
# 3  Thirty years after defeating the Galactic Empi...      136
# 4  Deckard Shaw seeks revenge against Dominic Tor...      137
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
# 3   Action|Adventure|Science Fiction|Fantasy
# 4                      Action|Crime|Thriller
#
#                                 production_companies release_date  \
# 0  Universal Studios|Amblin Entertainment|Legenda...     6/9/2015
# 1  Village Roadshow Pictures|Kennedy Miller Produ...    5/13/2015
# 2  Summit Entertainment|Mandeville Films|Red Wago...    3/18/2015
# 3          Lucasfilm|Truenorth Productions|Bad Robot   12/15/2015
# 4  Universal Pictures|Original Film|Media Rights ...     4/1/2015
#
#    vote_average  release_year      profit
# 0           6.5          2015  1363528810
# 1           7.1          2015   228436354
# 2           6.3          2015   185238201
# 3           7.5          2015  1868178225
# 4           7.3          2015  1316249360

# %%
data_h_b_cast = data_high_budget.assign(cast = data_high_budget['cast'].str.split('|'))\
.explode('cast').reset_index(drop = True)

data_h_b_cast.head(3)
# Out:
#      imdb_id     budget     revenue  original_title                 cast  \
# 0  tt0369610  150000000  1513528810  Jurassic World          Chris Pratt
# 1  tt0369610  150000000  1513528810  Jurassic World  Bryce Dallas Howard
# 2  tt0369610  150000000  1513528810  Jurassic World          Irrfan Khan
#
#           director            tagline  \
# 0  Colin Trevorrow  The park is open.
# 1  Colin Trevorrow  The park is open.
# 2  Colin Trevorrow  The park is open.
#
#                                             overview  runtime  \
# 0  Twenty-two years after the events of Jurassic ...      124
# 1  Twenty-two years after the events of Jurassic ...      124
# 2  Twenty-two years after the events of Jurassic ...      124
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2  Action|Adventure|Science Fiction|Thriller
#
#                                 production_companies release_date  \
# 0  Universal Studios|Amblin Entertainment|Legenda...     6/9/2015
# 1  Universal Studios|Amblin Entertainment|Legenda...     6/9/2015
# 2  Universal Studios|Amblin Entertainment|Legenda...     6/9/2015
#
#    vote_average  release_year      profit
# 0           6.5          2015  1363528810
# 1           6.5          2015  1363528810
# 2           6.5          2015  1363528810

# %%
data_h_b_cast.groupby(['cast'])['original_title'].count().sort_values(ascending = False)
# Out:
# cast
# Matt Damon           18
# Adam Sandler         17
# Angelina Jolie       16
# Eddie Murphy         15
# Samuel L. Jackson    15
#                      ..
# Leslie Bibb           1
# Leonard Nimoy         1
# Lennie James          1
# Lena Olin             1
# 50 Cent               1
# Name: original_title, Length: 1505, dtype: int64

# %%
answers['16'] = '3. Matt Damon'

# %% [markdown]
# # 17. В фильмах какого жанра больше всего снимался Nicolas Cage?

# %%
data_actor = data.copy()
data_actor.head(3)
# Out:
#      imdb_id     budget     revenue      original_title  \
# 0  tt0369610  150000000  1513528810      Jurassic World
# 1  tt1392190  150000000   378436354  Mad Max: Fury Road
# 2  tt2908446  110000000   295238201           Insurgent
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
#
#                       tagline  \
# 0           The park is open.
# 1          What a Lovely Day.
# 2  One Choice Can Destroy You
#
#                                             overview  runtime  \
# 0  Twenty-two years after the events of Jurassic ...      124
# 1  An apocalyptic story set in the furthest reach...      120
# 2  Beatrice Prior must confront her inner demons ...      119
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
#
#                                 production_companies release_date  \
# 0  Universal Studios|Amblin Entertainment|Legenda...     6/9/2015
# 1  Village Roadshow Pictures|Kennedy Miller Produ...    5/13/2015
# 2  Summit Entertainment|Mandeville Films|Red Wago...    3/18/2015
#
#    vote_average  release_year      profit
# 0           6.5          2015  1363528810
# 1           7.1          2015   228436354
# 2           6.3          2015   185238201

# %%
data_a = data_actor.assign(cast = data_actor.cast.str.split('|')).explode('cast').reset_index(drop = True)
data_a_g = data_a.assign(genres = data_a.genres.str.split('|')).explode('genres').reset_index(drop = True)

# %%
data_a_g.groupby(['cast'])['genres'].count().sort_values(ascending = False)
# Out:
# cast
# Nicolas Cage         93
# Samuel L. Jackson    89
# Matt Damon           79
# Bruce Willis         76
# Robert De Niro       67
#                      ..
# Ellen Pompeo          1
# Austin Crim           1
# Danny Strong          1
# Kuno Becker           1
# Chyler Leigh          1
# Name: genres, Length: 3406, dtype: int64

# %%
data_a_g_pivot = data_a_g.pivot_table(values = 'original_title', 
                    index = 'cast',
                    columns = 'genres',
                    aggfunc = 'count')
data_a_g_pivot
# Out:
# genres                   Action  Adventure  Animation  Comedy  Crime  \
# cast
# 50 Cent                     4.0        1.0        NaN     NaN    2.0
# A.J. Cook                   NaN        NaN        NaN     NaN    NaN
# Aaliyah                     1.0        NaN        NaN     NaN    1.0
# Aamir Khan                  NaN        NaN        NaN     1.0    NaN
# Aaran Thomas                NaN        NaN        NaN     NaN    1.0
# ...                         ...        ...        ...     ...    ...
# ZoÃ« Bell                   1.0        NaN        NaN     NaN    NaN
# ZoÃ« Borde                  NaN        NaN        NaN     NaN    NaN
# ZoÃ« Kravitz                1.0        1.0        NaN     NaN    NaN
# Zuleikha Robinson           NaN        1.0        NaN     NaN    NaN
# Ã“lafur Darri Ã“lafsson     1.0        1.0        NaN     NaN    NaN
#
# genres                   Documentary  Drama  Family  Fantasy  Foreign  \
# cast
# 50 Cent                          NaN    4.0     NaN      NaN      NaN
# A.J. Cook                        NaN    NaN     NaN      NaN      NaN
# Aaliyah                          NaN    1.0     NaN      1.0      NaN
# Aamir Khan                       NaN    1.0     NaN      NaN      NaN
# Aaran Thomas                     NaN    1.0     NaN      NaN      NaN
# ...                              ...    ...     ...      ...      ...
# ZoÃ« Bell                        NaN    NaN     NaN      NaN      NaN
# ZoÃ« Borde                       NaN    NaN     NaN      NaN      NaN
# ZoÃ« Kravitz                     NaN    NaN     NaN      NaN      NaN
# Zuleikha Robinson                NaN    NaN     NaN      NaN      NaN
# Ã“lafur Darri Ã“lafsson          NaN    NaN     NaN      1.0      NaN
#
# genres                   History  Horror  Music  Mystery  Romance  \
# cast
# 50 Cent                      NaN     NaN    NaN      NaN      NaN
# A.J. Cook                    NaN     1.0    NaN      1.0      NaN
# Aaliyah                      NaN     1.0    NaN      NaN      NaN
# Aamir Khan                   NaN     NaN    NaN      NaN      1.0
# Aaran Thomas                 NaN     NaN    NaN      NaN      NaN
# ...                          ...     ...    ...      ...      ...
# ZoÃ« Bell                    NaN     1.0    NaN      NaN      NaN
# ZoÃ« Borde                   NaN     1.0    NaN      NaN      NaN
# ZoÃ« Kravitz                 NaN     NaN    NaN      NaN      NaN
# Zuleikha Robinson            NaN     NaN    NaN      NaN      NaN
# Ã“lafur Darri Ã“lafsson      NaN     NaN    NaN      NaN      NaN
#
# genres                   Science Fiction  Thriller  War  Western
# cast
# 50 Cent                              NaN       3.0  NaN      NaN
# A.J. Cook                            NaN       NaN  NaN      NaN
# Aaliyah                              NaN       1.0  NaN      NaN
# Aamir Khan                           NaN       NaN  NaN      NaN
# Aaran Thomas                         NaN       1.0  NaN      NaN
# ...                                  ...       ...  ...      ...
# ZoÃ« Bell                            NaN       1.0  NaN      NaN
# ZoÃ« Borde                           NaN       1.0  NaN      NaN
# ZoÃ« Kravitz                         1.0       NaN  NaN      NaN
# Zuleikha Robinson                    NaN       NaN  NaN      1.0
# Ã“lafur Darri Ã“lafsson              NaN       NaN  NaN      NaN
#
# [3406 rows x 19 columns]

# %%
data_a_g_pivot.loc['Nicolas Cage'].sort_values(ascending = False)
# Out:
# genres
# Action             17.0
# Thriller           15.0
# Drama              12.0
# Crime              10.0
# Fantasy             8.0
# Adventure           7.0
# Comedy              6.0
# Science Fiction     4.0
# Mystery             3.0
# Family              3.0
# Animation           3.0
# History             2.0
# War                 1.0
# Romance             1.0
# Horror              1.0
# Documentary         NaN
# Foreign             NaN
# Music               NaN
# Western             NaN
# Name: Nicolas Cage, dtype: float64

# %%
answers['17'] = '2. Action'

# %% [markdown]
# # 18. Самый убыточный фильм от Paramount Pictures

# %%
data.columns
# Out:
# Index(['imdb_id', 'budget', 'revenue', 'original_title', 'cast', 'director',
#        'tagline', 'overview', 'runtime', 'genres', 'production_companies',
#        'release_date', 'vote_average', 'release_year', 'profit'],
#       dtype='object')

# %%
data.production_companies
# Out:
# 0       Universal Studios|Amblin Entertainment|Legenda...
# 1       Village Roadshow Pictures|Kennedy Miller Produ...
# 2       Summit Entertainment|Mandeville Films|Red Wago...
# 3               Lucasfilm|Truenorth Productions|Bad Robot
# 4       Universal Pictures|Original Film|Media Rights ...
#                               ...
# 1884    Twentieth Century Fox Film Corporation|Donners...
# 1885                                      New Line Cinema
# 1886    Universal Pictures|Capella International|KC Me...
# 1887    Laurence Mark Productions|Columbia Pictures Co...
# 1888                                Warner Bros. Pictures
# Name: production_companies, Length: 1889, dtype: object

# %%
data.assign(production_companies = data.production_companies\
            .str.split('|')).explode('production_companies').reset_index(drop=True)['profit'].min()
# Out:
# -165710090

# %%
data[data['profit'] == -165710090]
# Out:
#         imdb_id     budget   revenue   original_title  \
# 1245  tt1210819  255000000  89289910  The Lone Ranger
#
#                                                    cast        director  \
# 1245  Johnny Depp|Armie Hammer|William Fichtner|Hele...  Gore Verbinski
#
#                       tagline  \
# 1245  Never Take Off the Mask
#
#                                                overview  runtime  \
# 1245  The Texas Rangers chase down a gang of outlaws...      149
#
#                         genres  \
# 1245  Action|Adventure|Western
#
#                                    production_companies release_date  \
# 1245  Walt Disney Pictures|Jerry Bruckheimer Films|I...     7/3/2013
#
#       vote_average  release_year     profit
# 1245           6.0          2013 -165710090

# %%
data_production = data.assign(production_companies = data.production_companies\
            .str.split('|')).explode('production_companies').reset_index(drop=True)

# %%
data_production[data_production['production_companies'] == 'Paramount Pictures']['profit'].min()
# Out:
# -64831034

# %%
data_production[(data_production['profit'] == -64831034) & (data_production['production_companies'] == 'Paramount Pictures')]
# Out:
#         imdb_id     budget   revenue        original_title  \
# 2998  tt0267626  100000000  35168966  K-19: The Widowmaker
#
#                                                    cast         director  \
# 2998  Harrison Ford|Liam Neeson|Peter Sarsgaard|Joss...  Kathryn Bigelow
#
#                        tagline  \
# 2998  Fate has found its hero.
#
#                                                overview  runtime  \
# 2998  When Russia's first nuclear submarine malfunct...      138
#
#                       genres production_companies release_date  vote_average  \
# 2998  Thriller|Drama|History   Paramount Pictures    7/19/2002           6.0
#
#       release_year    profit
# 2998          2002 -64831034

# %%
answers['18'] = 'K-19: The Widowmaker (tt0267626)'

# %% [markdown]
# # 19. Какой год стал самым успешным по суммарным кассовым сборам?

# %%
data.groupby(['release_year'])['revenue'].sum().sort_values(ascending = False)
# Out:
# release_year
# 2015    25449202382
# 2014    23405862953
# 2013    23213799791
# 2012    23079001687
# 2011    22676791872
# 2010    21071204961
# 2009    20261791024
# 2008    18252781990
# 2007    18162406801
# 2004    15663430720
# 2005    15309425558
# 2006    14775042320
# 2003    14346123312
# 2002    14136361487
# 2001    13017764865
# 2000    10664099805
# Name: revenue, dtype: int64

# %%
data.release_year
# Out:
# 0       2015
# 1       2015
# 2       2015
# 3       2015
# 4       2015
#         ...
# 1884    2000
# 1885    2000
# 1886    2000
# 1887    2000
# 1888    2000
# Name: release_year, Length: 1889, dtype: int64

# %%
answers['19'] = '5. 2015'

# %% [markdown]
# # 20. Какой самый прибыльный год для студии Warner Bros?

# %%
data_p_pivot = data_production.pivot_table(values = ['profit'],
                           index = ['production_companies'],
                           columns = ['release_year'],
                           aggfunc = 'sum')

data_p_pivot
# Out:
#                                  profit                                       \
# release_year                       2000         2001         2002       2003
# production_companies
# "DIA" Productions GmbH & Co. KG     NaN          NaN          NaN  8350926.0
# 11:11 Mediaworks                    NaN          NaN          NaN        NaN
# 1492 Pictures                       NaN  781885067.0  776688482.0        NaN
# 1984 Private Defense Contractors    NaN          NaN          NaN        NaN
# 2 Entertain                         NaN          NaN          NaN        NaN
# ...                                 ...          ...          ...        ...
# Zippcast Films                      NaN          NaN          NaN        NaN
# Zohar International                 NaN          NaN          NaN        NaN
# Zucker/Netter Productions           NaN          NaN          NaN        NaN
# platinum studios                    NaN          NaN          NaN        NaN
# uFilm                               NaN          NaN          NaN        NaN
#
#                                                                          \
# release_year                             2004         2005         2006
# production_companies
# "DIA" Productions GmbH & Co. KG           NaN          NaN          NaN
# 11:11 Mediaworks                          NaN          NaN   94188334.0
# 1492 Pictures                     659804554.0  222250339.0  464480841.0
# 1984 Private Defense Contractors          NaN          NaN          NaN
# 2 Entertain                               NaN          NaN          NaN
# ...                                       ...          ...          ...
# Zippcast Films                            NaN          NaN          NaN
# Zohar International                       NaN          NaN          NaN
# Zucker/Netter Productions                 NaN          NaN          NaN
# platinum studios                          NaN          NaN          NaN
# uFilm                                     NaN          NaN          NaN
#
#                                                                        \
# release_year                             2007       2008         2009
# production_companies
# "DIA" Productions GmbH & Co. KG           NaN        NaN          NaN
# 11:11 Mediaworks                          NaN        NaN          NaN
# 1492 Pictures                     159047763.0        NaN  263106170.0
# 1984 Private Defense Contractors          NaN        NaN          NaN
# 2 Entertain                        20811672.0 -6795709.0          NaN
# ...                                       ...        ...          ...
# Zippcast Films                            NaN        NaN          NaN
# Zohar International                       NaN        NaN          NaN
# Zucker/Netter Productions                 NaN        NaN  280208309.0
# platinum studios                          NaN        NaN          NaN
# uFilm                                     NaN        NaN          NaN
#
#                                                                         \
# release_year                             2010         2011        2012
# production_companies
# "DIA" Productions GmbH & Co. KG           NaN          NaN         NaN
# 11:11 Mediaworks                          NaN          NaN         NaN
# 1492 Pictures                     131497209.0   99272124.0         NaN
# 1984 Private Defense Contractors          NaN   24806235.0  22930465.0
# 2 Entertain                               NaN          NaN         NaN
# ...                                       ...          ...         ...
# Zippcast Films                            NaN          NaN         NaN
# Zohar International                       NaN  602171856.0         NaN
# Zucker/Netter Productions                 NaN          NaN         NaN
# platinum studios                  -15365938.0   11822325.0         NaN
# uFilm                                     NaN  118432856.0         NaN
#
#
# release_year                            2013         2014        2015
# production_companies
# "DIA" Productions GmbH & Co. KG          NaN          NaN         NaN
# 11:11 Mediaworks                         NaN          NaN         NaN
# 1492 Pictures                     84578751.0  222424282.0         NaN
# 1984 Private Defense Contractors -36298836.0   25181600.0         NaN
# 2 Entertain                              NaN          NaN         NaN
# ...                                      ...          ...         ...
# Zippcast Films                           NaN          NaN  33571250.0
# Zohar International                      NaN          NaN         NaN
# Zucker/Netter Productions                NaN          NaN         NaN
# platinum studios                         NaN          NaN         NaN
# uFilm                                    NaN          NaN         NaN
#
# [1771 rows x 16 columns]

# %%
data_p_pivot.loc['Warner Bros.'].sort_values(ascending = False)
# Out:
#         release_year
# profit  2007            2.167368e+09
#         2008            2.134595e+09
#         2014            1.886304e+09
#         2011            1.871394e+09
#         2003            1.855493e+09
#         2010            1.853129e+09
#         2009            1.833482e+09
#         2004            1.675125e+09
#         2013            1.636453e+09
#         2005            1.551980e+09
#         2001            1.428175e+09
#         2012            1.258020e+09
#         2002            1.072249e+09
#         2015            8.703683e+08
#         2006            6.149896e+08
#         2000            4.713051e+08
# Name: Warner Bros., dtype: float64

# %%
data_production[data_production.production_companies.str.contains('Warner', na = False)]['production_companies'].unique()
# Out:
# array(['Warner Bros.', 'Warner Bros. Animation',
#        'Warner Bros. Interactive Entertainment', 'Warner Bros. Pictures',
#        'Warner Independent Pictures (WIP)'], dtype=object)

# %%
data.release_year.unique()
# Out:
# array([2015, 2014, 2009, 2010, 2001, 2008, 2011, 2002, 2012, 2003, 2013,
#        2005, 2006, 2004, 2007, 2000], dtype=int64)

# %%
data_production[data_production['production_companies'] == 'Warner Bros.']['release_year'].unique()
# Out:
# array([2015, 2014, 2009, 2010, 2001, 2008, 2011, 2002, 2012, 2003, 2013,
#        2005, 2006, 2004, 2007, 2000], dtype=int64)

# %%
data_Warner = data[data['production_companies'].str.contains('Warn', na = False)]
data_Warner.head()
# Out:
#       imdb_id     budget    revenue           original_title  \
# 11  tt1617661  176000003  183987723        Jupiter Ascending
# 22  tt2126355  110000000  470490832              San Andreas
# 40  tt1638355   75000000  108145109  The Man from U.N.C.L.E.
# 46  tt2361509   35000000  194564672               The Intern
# 59  tt1390411  100000000   93820758  In the Heart of the Sea
#
#                                                  cast  \
# 11  Mila Kunis|Channing Tatum|Sean Bean|Eddie Redm...
# 22  Dwayne Johnson|Alexandra Daddario|Carla Gugino...
# 40  Henry Cavill|Armie Hammer|Alicia Vikander|Eliz...
# 46  Robert De Niro|Anne Hathaway|Rene Russo|Anders...
# 59  Chris Hemsworth|Benjamin Walker|Cillian Murphy...
#
#                           director  \
# 11  Lana Wachowski|Lilly Wachowski
# 22                     Brad Peyton
# 40                     Guy Ritchie
# 46                    Nancy Meyers
# 59                      Ron Howard
#
#                                               tagline  \
# 11                              Expand your universe.
# 22  A rescue pilot survived an earthquake, this is...
# 40          Saving the world never goes out of style.
# 46                          Experience never gets old
# 59  Based on the incredible true story that inspir...
#
#                                              overview  runtime  \
# 11  In a universe where human genetic material is ...      124
# 22  In the aftermath of a massive earthquake in Ca...      114
# 40  At the height of the Cold War, a mysterious cr...      116
# 46  70-year-old widower Ben Whittaker has discover...      121
# 59  In the winter of 1820, the New England whaling...      122
#
#                                       genres  \
# 11  Science Fiction|Fantasy|Action|Adventure
# 22                     Action|Drama|Thriller
# 40                   Comedy|Action|Adventure
# 46                                    Comedy
# 59   Thriller|Drama|Adventure|Action|History
#
#                                  production_companies release_date  \
# 11  Village Roadshow Pictures|Dune Entertainment|A...     2/4/2015
# 22  New Line Cinema|Village Roadshow Pictures|Warn...    5/27/2015
# 40  Davis Entertainment|Warner Bros.|Wigram Produc...    8/13/2015
# 46                         Waverly Films|Warner Bros.    9/24/2015
# 59  Imagine Entertainment|Spring Creek Productions...   11/20/2015
#
#     vote_average  release_year     profit
# 11           5.2          2015    7987720
# 22           6.1          2015  360490832
# 40           7.0          2015   33145109
# 46           7.1          2015  159564672
# 59           6.4          2015   -6179242

# %%
data_Warner.groupby(['release_year'])['profit'].sum().sort_values(ascending = False)
# Out:
# release_year
# 2014    2295464519
# 2007    2208217007
# 2008    2134595031
# 2010    1974712985
# 2011    1871393682
# 2003    1855493377
# 2009    1822454136
# 2013    1636453400
# 2004    1631933725
# 2005    1595278228
# 2001    1343545668
# 2012    1258020056
# 2002    1022709901
# 2015     870368348
# 2006     617151739
# 2000     452631386
# Name: profit, dtype: int64

# %%
answers['20'] = '1. 2014'

# %% [markdown]
# # 21. В каком месяце за все годы суммарно вышло больше всего фильмов?

# %%
data.release_date
# Out:
# 0         6/9/2015
# 1        5/13/2015
# 2        3/18/2015
# 3       12/15/2015
# 4         4/1/2015
#            ...
# 1884     7/13/2000
# 1885    10/27/2000
# 1886     6/30/2000
# 1887     2/16/2000
# 1888     7/19/2000
# Name: release_date, Length: 1889, dtype: object

# %%
a = ' 6/9/2015'
func = lambda x: x[:2]
func(a)
# Out:
# ' 6'

# %%
data['month'] = data.release_date.apply(lambda x: x[:2])
data.head()
# Out:
#      imdb_id     budget     revenue                original_title  \
# 0  tt0369610  150000000  1513528810                Jurassic World
# 1  tt1392190  150000000   378436354            Mad Max: Fury Road
# 2  tt2908446  110000000   295238201                     Insurgent
# 3  tt2488496  200000000  2068178225  Star Wars: The Force Awakens
# 4  tt2820852  190000000  1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                          tagline  \
# 0              The park is open.
# 1             What a Lovely Day.
# 2     One Choice Can Destroy You
# 3  Every generation has a story.
# 4            Vengeance Hits Home
#
#                                             overview  runtime  \
# 0  Twenty-two years after the events of Jurassic ...      124
# 1  An apocalyptic story set in the furthest reach...      120
# 2  Beatrice Prior must confront her inner demons ...      119
# 3  Thirty years after defeating the Galactic Empi...      136
# 4  Deckard Shaw seeks revenge against Dominic Tor...      137
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
# 3   Action|Adventure|Science Fiction|Fantasy
# 4                      Action|Crime|Thriller
#
#                                 production_companies release_date  \
# 0  Universal Studios|Amblin Entertainment|Legenda...     6/9/2015
# 1  Village Roadshow Pictures|Kennedy Miller Produ...    5/13/2015
# 2  Summit Entertainment|Mandeville Films|Red Wago...    3/18/2015
# 3          Lucasfilm|Truenorth Productions|Bad Robot   12/15/2015
# 4  Universal Pictures|Original Film|Media Rights ...     4/1/2015
#
#    vote_average  release_year      profit month
# 0           6.5          2015  1363528810    6/
# 1           7.1          2015   228436354    5/
# 2           6.3          2015   185238201    3/
# 3           7.5          2015  1868178225    12
# 4           7.3          2015  1316249360    4/

# %%
def cleaning(x):
    print(x)
    print(type(x))
    if x.str.match('/', na = False):
        return x[:1]
    else:
        return x

# %%
data_test = data.copy()

# %%
data_test.month.apply(cleaning_)
# Out:
# 0
# 1
# 2
# 3
# 4
#        ..
# 1884
# 1885
# 1886
# 1887
# 1888
# Name: month, Length: 1889, dtype: object

# %%
data_test['month'] = data_test.month.apply(cleaning_)
data_test.head()
# Out:
#      imdb_id     budget     revenue                original_title  \
# 0  tt0369610  150000000  1513528810                Jurassic World
# 1  tt1392190  150000000   378436354            Mad Max: Fury Road
# 2  tt2908446  110000000   295238201                     Insurgent
# 3  tt2488496  200000000  2068178225  Star Wars: The Force Awakens
# 4  tt2820852  190000000  1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                          tagline  \
# 0              The park is open.
# 1             What a Lovely Day.
# 2     One Choice Can Destroy You
# 3  Every generation has a story.
# 4            Vengeance Hits Home
#
#                                             overview  runtime  \
# 0  Twenty-two years after the events of Jurassic ...      124
# 1  An apocalyptic story set in the furthest reach...      120
# 2  Beatrice Prior must confront her inner demons ...      119
# 3  Thirty years after defeating the Galactic Empi...      136
# 4  Deckard Shaw seeks revenge against Dominic Tor...      137
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
# 3   Action|Adventure|Science Fiction|Fantasy
# 4                      Action|Crime|Thriller
#
#                                 production_companies release_date  \
# 0  Universal Studios|Amblin Entertainment|Legenda...     6/9/2015
# 1  Village Roadshow Pictures|Kennedy Miller Produ...    5/13/2015
# 2  Summit Entertainment|Mandeville Films|Red Wago...    3/18/2015
# 3          Lucasfilm|Truenorth Productions|Bad Robot   12/15/2015
# 4  Universal Pictures|Original Film|Media Rights ...     4/1/2015
#
#    vote_average  release_year      profit month
# 0           6.5          2015  1363528810     6
# 1           7.1          2015   228436354     5
# 2           6.3          2015   185238201     3
# 3           7.5          2015  1868178225
# 4           7.3          2015  1316249360     4

# %%
data_test[['release_date','month']]
# Out:
#      release_date month
# 0        6/9/2015     6
# 1       5/13/2015     5
# 2       3/18/2015     3
# 3      12/15/2015
# 4        4/1/2015     4
# ...           ...   ...
# 1884    7/13/2000     7
# 1885   10/27/2000
# 1886    6/30/2000     6
# 1887    2/16/2000     2
# 1888    7/19/2000     7
#
# [1889 rows x 2 columns]

# %%
def cleaning_(x):
    index = x.find('/')
    if index == -1:
        return ' '
    else:
        return x[:index]

# %%
data_test['month'] = data_test['release_date'].apply(lambda x:  x.month)

# %%
import datetime

date1 = '5/27/2015'
date1 = datetime.datetime.strptime(date1, '%m/%d/%Y')

date1
# Out:
# datetime.datetime(2015, 5, 27, 0, 0)

# %%
date1.month
# Out:
# 5

# %%
def month(date):
    date = datetime.datetime.strptime(date, '%m/%d/%Y')
    return date

# %%
data_test['release_date'] = data_test['release_date'].apply(month)

# %%
data_test.head(2)
# Out:
#      imdb_id     budget     revenue      original_title  \
# 0  tt0369610  150000000  1513528810      Jurassic World
# 1  tt1392190  150000000   378436354  Mad Max: Fury Road
#
#                                                 cast         director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...    George Miller
#
#               tagline                                           overview  \
# 0   The park is open.  Twenty-two years after the events of Jurassic ...
# 1  What a Lovely Day.  An apocalyptic story set in the furthest reach...
#
#    runtime                                     genres  \
# 0      124  Action|Adventure|Science Fiction|Thriller
# 1      120  Action|Adventure|Science Fiction|Thriller
#
#                                 production_companies release_date  \
# 0  Universal Studios|Amblin Entertainment|Legenda...   2015-06-09
# 1  Village Roadshow Pictures|Kennedy Miller Produ...   2015-05-13
#
#    vote_average  release_year      profit month
# 0           6.5          2015  1363528810    6/
# 1           7.1          2015   228436354    5/

# %%
data_test['month'] = data_test['release_date'].apply(lambda x: x.month)

# %%
data_test.head(2)
# Out:
#      imdb_id     budget     revenue      original_title  \
# 0  tt0369610  150000000  1513528810      Jurassic World
# 1  tt1392190  150000000   378436354  Mad Max: Fury Road
#
#                                                 cast         director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...    George Miller
#
#               tagline                                           overview  \
# 0   The park is open.  Twenty-two years after the events of Jurassic ...
# 1  What a Lovely Day.  An apocalyptic story set in the furthest reach...
#
#    runtime                                     genres  \
# 0      124  Action|Adventure|Science Fiction|Thriller
# 1      120  Action|Adventure|Science Fiction|Thriller
#
#                                 production_companies release_date  \
# 0  Universal Studios|Amblin Entertainment|Legenda...   2015-06-09
# 1  Village Roadshow Pictures|Kennedy Miller Produ...   2015-05-13
#
#    vote_average  release_year      profit  month
# 0           6.5          2015  1363528810      6
# 1           7.1          2015   228436354      5

# %%
data_test.groupby(['month'])['imdb_id'].count().sort_values(ascending = False)
# Out:
# month
# 9     227
# 12    190
# 10    186
# 8     161
# 3     156
# 4     149
# 6     147
# 11    146
# 7     142
# 5     140
# 2     135
# 1     110
# Name: imdb_id, dtype: int64

# %%
answers['21'] = '4. Сентябрь'

# %% [markdown]
# # 22. Сколько суммарно вышло фильмов летом? (за июнь, июль, август)

# %%
data_test.query('5< month <9')['month'].unique()
# Out:
# array([6, 7, 8], dtype=int64)

# %%
data_test.query('5< month <9')['month'].count()
# Out:
# 450

# %%
answers['22'] = '2. 450'

# %% [markdown]
# # 23. Для какого режиссера зима – самое продуктивное время года?

# %% [markdown]
# # 24. Какая студия дает самые длинные названия своим фильмам по количеству символов?

# %% [markdown]
# # 25. Описание фильмов какой студии в среднем самые длинные по количеству слов?

# %% [markdown]
# # 26. Какие фильмы входят в 1 процент лучших по рейтингу?
# по vote_average

# %% [markdown]
# # 27. Какие актеры чаще всего снимаются в одном фильме вместе?

# %% [markdown]
# ВАРИАНТ 2

# %% [markdown]
# # Submission

# %%
# в конце можно посмотреть свои ответы к каждому вопросу
answers
# Out:
# {'1': '...', '2': '...'}

# %%
# и убедиться что ни чего не пропустил)
len(answers)
